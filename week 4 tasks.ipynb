# %% [markdown]
# # Task1
# ### :Import libraries (Numpy, pandas, matplotlib, plotly and seaborn) and then read csv file.

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Read the CSV file into a pandas DataFrame
file_path = "C:\\Users\\LENOVO\\Downloads\\menu.csv"  
df = pd.read_csv(file_path)

df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %% [markdown]
# # Task2
# ### Check statistical facts by checking all columns. Then calculate the maximum value of the following attributes ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (%Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']

# %%
# Display statistical facts for all columns
statistical_facts = df.describe()

# Display the maximum value for the specified attributes
max_values = df[['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein',
                 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']].max()

# Display the results
print("Statistical Facts:")
print(statistical_facts)

print("\nMaximum Values:")
print(max_values)
# Out:
# Statistical Facts:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# # Task3
# ### Check to see if infact there is any correlation between Calories and other independent variables by plotting a correlation matrix next.

# %%
# Create a heatmap 
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f", linewidths=0.5)

# Place x-axis labels at the top
heatmap.xaxis.tick_top()

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='left')

plt.title('Correlation Matrix between Calories and Other Variables')
plt.show()

# %% [markdown]
# # Task4
# ### : Draw boxplot for Calories vs Category to spot outliers and max calories category

# %%
# Create a boxplot for Calories vs Category
plt.figure(figsize=(12, 8))
sns.boxplot(x='Calories', y='Category', data=df, palette='husl')
plt.title('Boxplot of Calories vs Category')
plt.show()

# %% [markdown]
# # Task5
# ### Figure out which exact item contains a high quantity for ['Calories', 'Total Fat', 'Carbohydrates','Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium(% Daily Value)', 'Iron (% Daily Value)'.

# %%
# Specify the attributes to analyze
attributes = ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein',
              'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']

# Find the item(s) with the maximum value for each attribute
max_items = {}
for attribute in attributes:
    max_index = df[attribute].idxmax()
    max_item = df.loc[max_index, 'Item']
    max_items[attribute] = {'Item': max_item, 'Value': df.loc[max_index, attribute]}

# Display the results
for attribute, details in max_items.items():
    print(f"{attribute}: {details['Item']} - {details['Value']}")
# Out:
# Calories: Chicken McNuggets (40 piece) - 1880
# Total Fat: Chicken McNuggets (40 piece) - 118.0
# Carbohydrates: Chocolate Shake (Large) - 141
# Dietary Fiber: Big Breakfast with Hotcakes (Large Biscuit) - 7
# Sugars: McFlurry with M&M’s Candies (Medium) - 128
# Protein: Chicken McNuggets (40 piece) - 87
# Vitamin A (% Daily Value): Premium Bacon Ranch Salad (without Chicken) - 170
# Vitamin C (% Daily Value): Minute Maid Orange Juice (Large) - 240
# Calcium (% Daily Value): Strawberry Shake (Large) - 70
# Iron (% Daily Value): Big Breakfast with Hotcakes (Regular Biscuit) - 40

# %% [markdown]
# # Task6
# ### Draw Stripplot for each category against the following attributes ['Calories', 'Total Fat','Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein','Vitamin A (% Daily Value)','Vitamin C (% Daily Value)','Calcium (% Daily Value)', 'Iron(% Daily Value)'.

# %%
# Specify the attributes to analyze
attributes = ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein',
              'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']

# Set up subplots for each attribute
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(15, 20))
fig.subplots_adjust(hspace=0.5)

# Flatten the axes for easy iteration
axes = axes.flatten()

# Define a color palette for each category
category_palette = sns.color_palette('muted', n_colors=len(df['Category'].unique()))

# Draw stripplots for each category against each attribute with different colors
for i, attribute in enumerate(attributes):
    sns.stripplot(x='Category', y=attribute, data=df, ax=axes[i], jitter=True, palette=category_palette)
    axes[i].set_title(f'Stripplot of {attribute} by Category')
    axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis labels for better readability

plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11180\4068138011.py:17: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Category', y=attribute, data=df, ax=axes[i], jitter=True, palette=category_palette)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11180\4068138011.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis labels for better readability
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11180\4068138011.py:17: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='Category', y=attribute, data=df, ax=axes[i], jitter=True, palette=category_palette)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11180\4068138011.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...

# %% [markdown]
# # Task7
# ### Draw a horizontal bar graph for items in each category against the calories. Here is one sample for all items in Beef & Pork, you have to do it for items in each category. Also, write your observation.

# %%
# Sort the DataFrame by Calories in ascending order
category_df = category_df.sort_values(by='Calories', ascending=True)

# Plot a horizontal bar graph for items in the selected category against calories in ascending order
plt.figure(figsize=(12, 8))
sns.barplot(x='Calories', y='Item', data=category_df, color='blue')
plt.title(f'Calories in Items - {category_to_plot}')
plt.xlabel('Calories')
plt.ylabel('Item')
plt.show()

# %% [markdown]
# ### Observation:
# according to my observation the least amount of calories are in hamburger falling between 200 to 300 calories and the highest amount of calories are in Double Quater Pounder with cheeze that is above 700 calories
